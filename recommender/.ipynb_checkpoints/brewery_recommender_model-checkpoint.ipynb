# %% [markdown]
# # Brewery Recommender

# %%
int_list = [1,1, 1,2,3,4,3,4]
count = 1
num_dict = {}
sort_list = sorted(int_list)
for i in range(1, len(sort_list)):
    if sort_list[i] == sort_list[i-1]:
        print('num : ', sort_list[i])
        count += 1
        print(count)
        if i == len(sort_list) - 1:
            num_dict[str(sort_list[i])] = count
    else:
        print('num_new : ', sort_list[i-1])
        num_dict[str(sort_list[i-1])] = count
        count = 1
# Out:
# num :  1
# 2
# num :  1
# 3
# num_new :  1
# num_new :  2
# num :  3
# 2
# num_new :  3
# num :  4
# 2

# %%
smallest = min(num_dict)
for key, value in num_dict.items():
    print('k: ', key)
    print('v: ', value)
    print('small: ', smallest)
    if value == smallest:
        print('hi')
        print(key)
# Out:
# k:  1
# v:  3
# small:  1
# k:  2
# v:  1
# small:  1
# k:  3
# v:  2
# small:  1
# k:  4
# v:  2
# small:  1

# %%
sorted(num_dict.items())
# Out:
# [('1', 3), ('2', 1), ('3', 2)]

# %%
# importing libraries
import pandas as pd
import sys
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances
import matplotlib.pyplot as plt

from tqdm import tqdm
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
# reading in data
df = pd.read_csv('../data/beer_reviews_col_drop.csv')
df.head()
# Out:
#               brewery_name  review_overall review_profilename  \
# 0  Caldera Brewing Company             3.0            oline73
# 1  Caldera Brewing Company             3.5          Reidrover
# 2  Caldera Brewing Company             3.0       alpinebryant
# 3  Caldera Brewing Company             4.0      LordAdmNelson
# 4  Caldera Brewing Company             4.5       augustgarage
#
#              beer_name
# 0  Caldera Ginger Beer
# 1  Caldera Ginger Beer
# 2  Caldera Ginger Beer
# 3  Caldera Ginger Beer
# 4  Caldera Ginger Beer

# %%
# %%time
# using a pivot table to create my recommender model
pivot = df.pivot_table(index='beer_name', columns='review_profilename', 
                       values=['review_overall'])

pivot_sparse = sparse.csr_matrix(pivot.fillna(0))
recommender = pairwise_distances(pivot_sparse, metric='cosine')
recommender_df = pd.DataFrame(recommender, index=pivot.index, columns=pivot.index)

# clearing everything I don't need for the model to save memory
pivot = []
recommender = []
pivot_sparse = []
# Out:
# CPU times: user 3min 18s, sys: 2min 26s, total: 5min 44s
# Wall time: 6min 30s

# %%
# HOLY COW!!! the recommender takes up a lot of memory so it will slow down my function...
recommender_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37895 entries, "100" to Ω-naught (Omeganaught)
# Columns: 37895 entries, "100" to Ω-naught (Omeganaught)
# dtypes: float64(37895)
# memory usage: 10.7+ GB

# %%
# %%time
# making sure the recommender works for 1 beer first
recommender_df['\"400\" Ale'].sort_values()[1:10]
# Out:
# CPU times: user 36.5 ms, sys: 289 ms, total: 326 ms
# Wall time: 738 ms
# beer_name
# Milly's Labyrinth                          0.636757
# Milly's Lil' Ivan's Foreign Extra Stout    0.683922
# Portsmouth Junebock                        0.688553
# India Special Reserve Beer                 0.695276
# Guinness Foreign Extra Stout (Jamaica)     0.705559
# Milly's Hopzilla                           0.706863
# Olde Richmond Batch No. 9 Red Ale          0.709080
# Weyermann Imperial India Pale Ale          0.716571
# Moat Golden Dog Pilsner                    0.728785
# Name: "400" Ale, dtype: float64

# %%
def brewery_recommender(user):
    # creating a list of the 20 most similar beers if the user rated these beers equal to or above 3.5 (0-5 scale)
    recs = []
    for key, value in user.items():
        rec = {}
        if value >= 3.5:
            rec[key] = recommender_df[key].sort_values()[1:11]
            recs.append(rec)

    beer_checklist = []
    
    for i in recs:
        # creating a list of beers to read back into the dataset to score breweries if the similarity score for that
        # beer is greater than or equal to 0.5
        for beer, scores in i.items():
            for recom, sim_scores in scores.items():
#                 if sim_scores <= 0.5:
                beer_checklist.append((recom, sim_scores))
 
    
    # creating a list of breweries and the beer scores associated with that brewery to find the most 
    # similar brewery based on the mean similarity score
    breweries = []
    current_beer = ''
    for beer in beer_checklist:
        for index, brewery in df[df['beer_name'] == beer[0]]['brewery_name'].items():
            if current_beer != beer[0]:
                current_beer = beer[0] 
                brewery_score = (brewery, beer[1])
                breweries.append(brewery_score) 
                
    # sorting the breweries alphabetically to make it easier to loop through
    current_brewery = ''
    scores = []
    brewery_dict = {}
    breweries_sort = sorted(breweries)
    for i in range(len(breweries_sort)):
        if breweries_sort[i][0] == current_brewery:
            scores.append(breweries_sort[i][1])
        else:
            if current_brewery:
                brewery_dict[current_brewery] = scores
            current_brewery = breweries_sort[i][0]
            scores = []
            scores.append(breweries_sort[i][1])
    return brewery_dict

# creating a random user that will rate num_beers on a 0-5 uniform distribution scale
def random_beer_sample(num_beers):
    beers = df['beer_name'].sample(n=num_beers, random_state=42) 
    np.random.seed(6)
    ratings = []
    user_ratings = {}
    for i in beers:
        user_ratings[i] = np.random.uniform(high=5.0)
    return user_ratings

# sorting the breweries mean similarity scores and counting the number of similar beers at that brewery 
# similar beers are beers with similarity scores less than 0.5
def sorting_brewery_scores(n_beers):
    rand_user = random_beer_sample(n_beers)
    best_breweries = {}
    for brewery, score in brewery_recommender(rand_user).items():
        sim_beers = 0
        for i in score:
            if i < 0.5:
                sim_beers += 1
                
        if 2 <= sim_beers:
            if np.mean(score) < 0.75:
                best_breweries[brewery] = (np.mean(score), 'number of similar beers: ', sim_beers)
            else:
                continue
        
    sorted_best_breweries = (sorted(best_breweries.items(), key = 
                 lambda kv:(kv[1], kv[0])))
    if len(sorted_best_breweries) > 3:
        sorted_best_breweries = sorted_best_breweries[:3]
    
    return sorted_best_breweries

# %%
# %%time
sorting_brewery_scores(20)
# Out:
# CPU times: user 4.79 s, sys: 959 ms, total: 5.75 s
# Wall time: 5.9 s
# [('Brasseurs Du Nord Inc.',
#   (0.4507354381162824, 'number of similar beers: ', 2)),
#  ('AleSmith Brewing Company',
#   (0.4739980689222205, 'number of similar beers: ', 2))]

# %%
# %%time
sorting_brewery_scores(10)
# Out:
# CPU times: user 1.41 s, sys: 11.5 ms, total: 1.42 s
# Wall time: 1.42 s
# [('AleSmith Brewing Company',
#   (0.4739980689222205, 'number of similar beers: ', 2))]

# %%
# %%time
sorting_brewery_scores(100)
# Out:
# CPU times: user 23.5 s, sys: 4.44 s, total: 27.9 s
# Wall time: 28.8 s
# [('Browarmia Królewkska',
#   (0.11641194017073209, 'number of similar beers: ', 2)),
#  ('Bierhalle', (0.23023686415065453, 'number of similar beers: ', 2)),
#  ('Brasseurs Du Nord Inc.',
#   (0.4507354381162824, 'number of similar beers: ', 2))]

# %%
# %%time
sorting_brewery_scores(500)
# Out:
# CPU times: user 1min 43s, sys: 31.6 s, total: 2min 14s
# Wall time: 2min 44s
# [('Browarmia Królewkska',
#   (0.11641194017073209, 'number of similar beers: ', 2)),
#  ('Flossmoor Station Restaurant & Brewery',
#   (0.21805674916971007, 'number of similar beers: ', 2)),
#  ('Bierhalle', (0.23023686415065453, 'number of similar beers: ', 2))]

# %% [markdown]
# # Scraping ratebeer

# %%
# scraping for dc breweries
url = 'https://www.ratebeer.com/breweries/washington-dc/48/213/'
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'lxml')

# %%
dc_breweries = []
for i in soup.find_all('div', {'class' : 'tab-pane active searchable'}):
    for j in i.find_all('table', {'id' : 'brewerTable'}):
        for k in j.find_all('td'):
            try:
                dc_breweries.append(k.find('a').text)
            except:
                pass

# %%
dc_breweries_spaces = []
for i in dc_breweries:
    dc_breweries_spaces.append(i.strip())

# %%
dc_breweries_spaces
# Out:
# ['3 Stars Brewing Company',
#  'Atlas Brew Works',
#  'Bardo Brewing',
#  'Bluejacket',
#  'ChopHouse & Brewery D.C. (Craftworks)',
#  'DC Brau Brewing Company',
#  'Georgetown Trading Company',
#  'Hellbender Brewing Company',
#  'Red Bear Brewing Company',
#  'Right Proper Brewing Company',
#  'Sankofa Beer Company',
#  'The Public Option',
#  'The Pug',
#  'Valor Brewpub']

# %%
df[df['brewery_name'].str.contains('Port City')]
# Out:
#         brewery_id       brewery_name         review_time  review_overall  \
# 459401       24791  Port City Brewing 2012-01-01 01:07:46             3.5
# 459402       24791  Port City Brewing 2011-12-17 23:17:13             3.5
# 459403       24791  Port City Brewing 2011-12-10 02:53:24             4.0
# 459404       24791  Port City Brewing 2011-12-02 23:08:46             2.0
# 459405       24791  Port City Brewing 2011-11-02 02:19:32             3.5
# 459406       24791  Port City Brewing 2011-11-01 23:07:56             3.5
# 459407       24791  Port City Brewing 2011-09-30 20:41:14             5.0
# 459408       24791  Port City Brewing 2011-08-22 23:00:17             4.0
# 459409       24791  Port City Brewing 2011-08-22 11:58:08             3.0
# 459410       24791  Port City Brewing 2011-08-19 20:18:59             3.5
# 459411       24791  Port City Brewing 2011-08-09 16:37:58             3.5
# 459412       24791  Port City Brewing 2011-08-09 03:30:31             3.5
# 459413       24791  Port City Brewing 2011-07-16 23:30:57             3.5
# 459414       24791  Port City Brewing 2011-06-09 15:49:48             3.0
# 459415       24791  Port City Brewing 2011-06-08 19:24:47             3.0
# 459416       24791  Port City Brewing 2011-05-25 23:49:50             4.0
# 459417       24791  Port City Brewing 2011-05-25 04:11:39             3.0
# 459418       24791  Port City Brewing 2011-05-23 05:33:14             3.5
# 459419       24791  Port City Brewing 2011-02-07 04:45:30             4.0
# 459420       24791  Port City Brewing 2011-05-21 21:03:38             3.5
# 459421       24791  Port City Brewing 2011-05-21 01:49:29             3.5
# 459422       24791  Port City Brewing 2011-05-17 02:11:53             4.0
# 459423       24791  Port City Brewing 2011-04-12 01:20:58             3.5
# 459424       24791  Port City Brewing 2011-04-10 00:08:48             3.5
# 459425       24791  Port City Brewing 2011-04-09 03:32:00             3.0
# 459426       24791  Port City Brewing 2011-02-24 22:15:02             2.0
# 459427       24791  Port City Brewing 2011-02-22 06:22:30             4.0
# 459428       24791  Port City Brewing 2011-02-09 01:36:17             4.0
# 459429       24791  Port City Brewing 2011-10-19 17:50:28             4.0
