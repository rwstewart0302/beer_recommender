# %% [markdown]
# # Collecting All US Breweries

# %%
# Package data for using openbrewerydb to pull brewery data
import pandas as pd
import requests
import openbrewerydb

# %%
# default loader is for all states and all cities
breweries = openbrewerydb.load()
breweries.head()
# Out:
#   brewery_type        city        country  id   latitude   longitude  \
# 0        micro  Birmingham  United States   2  33.524521  -86.774322
# 1        micro  Birmingham  United States  44  33.512849  -86.791400
# 2        micro  Huntsville  United States  46  34.727752  -86.593201
# 3        micro     Wasilla  United States  55  61.575269 -149.412710
# 4        micro   Anchorage  United States  76  61.138489 -149.879076
#
#                        name       phone postal_code    state  \
# 0       Avondale Brewing Co  2057775456  35222-1932  Alabama
# 1          Trim Tab Brewing  2057030536  35233-3401  Alabama
# 2      Yellowhammer Brewery  2569755950  35805-3046  Alabama
# 3  Bearpaw River Brewing Co              99654-7679   Alaska
# 4    King Street Brewing Co  9073365464       99515   Alaska
#
#                       street tag_list                updated_at  \
# 0              201 41st St S       []  2018-08-23T23:19:57.825Z
# ...

# %%
breweries.to_csv("../data/breweries_50_states.csv", index=False)
